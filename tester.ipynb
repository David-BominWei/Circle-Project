# %%
from circle.circle_detection_data import show_circle, noisy_circle, generate_examples

noisy_circle(100,15,25,0.25)
# Out:
# (array([[0.63360837, 0.6965345 , 0.54580507, ..., 0.26447197, 0.72347326,
#          0.48428359],
#         [0.69743349, 0.75308185, 0.25493424, ..., 0.3735122 , 0.54145164,
#          0.38875962],
#         [0.23224245, 0.51236911, 0.36180215, ..., 0.31542494, 0.59091839,
#          0.2126721 ],
#         ...,
#         [0.61558071, 0.58328572, 0.36230353, ..., 0.84959846, 0.62810397,
#          0.69093225],
#         [0.49137538, 0.40427483, 0.50125297, ..., 0.28583342, 0.52007436,
#          0.19565145],
#         [0.7127214 , 0.27497535, 0.72747206, ..., 0.18971657, 0.24900178,
#          0.67914912]]),
#  CircleParams(row=56, col=90, radius=24))

# %%
generator = iter(generate_examples())

# %%
next(generator)
# Out:
# Using parameters: noise_level=0.5, img_size=100, min_radius=10, max_radius=50, dataset_path='ds'
# (array([[ 0.34283915,  0.20443205,  0.30859184, ...,  0.65372986,
#           0.17105677,  0.58860318],
#         [ 0.08856627, -0.02643685,  0.39625614, ...,  0.34931773,
#          -0.32387659,  0.54616927],
#         [ 0.61908457,  0.46396104,  0.47922789, ...,  0.35743048,
#           1.09651724,  0.8596554 ],
#         ...,
#         [ 1.09974765,  1.285634  ,  0.54640151, ...,  0.90552831,
#           0.61002422,  0.52179005],
#         [ 0.62626187,  0.94301308,  0.19803075, ...,  1.13752405,
#           0.83922624,  1.00933615],
#         [ 0.9016836 ,  0.18256668,  1.56323899, ...,  1.40918655,
#           0.40487717,  0.77429556]]),
#  CircleParams(row=87, col=93, radius=34))

# %%
show_circle(noisy_circle(100,15,25,0.25)[0])
