# %%
from circle.circle_detection_data import show_circle, noisy_circle, generate_examples

noisy_circle(100,15,25,0.25)

# %%
generator = iter(generate_examples())

# %%
next(generator)

# %%
show_circle(noisy_circle(100,15,25,0.25)[0])

# %%
from circleDataset import FixCircleDataset
from torch.utils.data import DataLoader
from network import Network
from circle.circle_detection_data import show_circle, noisy_circle, generate_examples
import numpy as np
import os

os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
test_loader = DataLoader(FixCircleDataset(data_size=64), batch_size=64, shuffle=True)
model = Network()

show_circle(np.array(model(next(iter(test_loader))[0])[0]))
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 3110.71it/s]
